# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader,TensorDataset
import torch.optim as optim

# %%
import sys
sys.path.append('../../utils/')

# %%
from Bias_Variance_Estimator import estimate_bias_variance_mse

# %%
def generate_sinusoid_data(num_samples:int,noise_scale:float=0.3):
    X = np.linspace(-1,1,num_samples).reshape(-1, 1)
    y_true = np.sin(2 * np.pi * X)                       # shape: (num_samples, 1)
    noise = np.random.normal(0, noise_scale, size=(num_samples, 1))#random gaussian noise
    y = y_true + noise
    return X,y

# %%
NUM_TRAIN_SAMPLES = 5000
NUM_TEST_SAMPLES = 1000
BOOTSTRAP_NUMS = 20
MAX_EPOCHS = 500
PATIENCE = 500
LEARNING_RATE=0.001

# %%
import torch
import torch.nn as nn

# Define a single residual block
class ResidualBlock(nn.Module):
    def __init__(self, hidden_dim):
        super().__init__()
        self.block = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU()
        )
    
    def forward(self, x):
        return self.block(x) + x

class MLPRegressor(nn.Module):
    def __init__(self, input_dim, hidden_dim, depth, output_dim=1):
        super().__init__()
        layers = []
        
        # input layer
        layers.append(nn.Linear(input_dim, hidden_dim))
        layers.append(nn.ReLU())
        
        # hidden layers with residuals
        for _ in range(depth - 1):
            layers.append(ResidualBlock(hidden_dim))
        ## output layer
        layers.append(nn.Linear(hidden_dim, output_dim))
        self.net = nn.Sequential(*layers)
    
    def forward(self, x):
        return self.net(x)

# Example usage
mlp = MLPRegressor(input_dim=10, hidden_dim=64, depth=10)
print(mlp)
# Out:
# MLPRegressor(
#   (net): Sequential(
#     (0): Linear(in_features=10, out_features=64, bias=True)
#     (1): ReLU()
#     (2): ResidualBlock(
#       (block): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=64, out_features=64, bias=True)
#         (3): ReLU()
#       )
#     )
#     (3): ResidualBlock(
#       (block): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=64, out_features=64, bias=True)
#         (3): ReLU()
#       )
#     )
#     (4): ResidualBlock(
#       (block): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=64, out_features=64, bias=True)
#         (3): ReLU()
#       )
#     )
#     (5): ResidualBlock(
#       (block): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=64, out_features=64, bias=True)
#         (3): ReLU()
#       )
#     )
#     (6): ResidualBlock(
#       (block): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=64, out_features=64, bias=True)
#         (3): ReLU()
#       )
#     )
#     (7): ResidualBlock(
#       (block): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=64, out_features=64, bias=True)
#         (3): ReLU()
#       )
#     )
#     (8): ResidualBlock(
#       (block): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=64, out_features=64, bias=True)
#         (3): ReLU()
#       )
#     )
#     (9): ResidualBlock(
#       (block): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=64, out_features=64, bias=True)
#         (3): ReLU()
#       )
#     )
#     (10): ResidualBlock(
#       (block): Sequential(
#         (0): Linear(in_features=64, out_features=64, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=64, out_features=64, bias=True)
#         (3): ReLU()
#       )
#     )
#     (11): Linear(in_features=64, out_features=1, bias=True)
#   )
# )

# %%
X_train,y_train = generate_sinusoid_data(num_samples=NUM_TRAIN_SAMPLES)
X_test,y_test = generate_sinusoid_data(num_samples=NUM_TEST_SAMPLES,noise_scale=0)

# %%
depths = [1,2,4,8,16,32]

# %%
hidden_units=128
depth_results= []
for d in depths:
    print(f"\n*** Running experiment for network with {d} depth***")
    bias_sq, variance, total_error,error_sum,avg_train_loss = estimate_bias_variance_mse(
            model_class=MLPRegressor,
            X_train=X_train,
            y_train=y_train,
            X_test=X_test,
            y_test=y_test,
            loss_fn=nn.MSELoss(),
            model_kwargs={'input_dim':X_train.shape[1],"hidden_dim":hidden_units,'depth':d},
            num_models=BOOTSTRAP_NUMS,
            max_epochs=MAX_EPOCHS,
            patience=PATIENCE,
            lr=LEARNING_RATE,
            batch_size=128
        )
    depth_results.append({
            'depth': d,
            'bias_sq': bias_sq,
            'variance': variance,
            'total_error': total_error,
            'error_sum': error_sum,
            'avg_train_loss':avg_train_loss
        })
# Out:
# *** Running experiment for network with 1 depth***
# Starting experiment with 20 models...
#
# --- Training Model 1/20 ---
#
# --- Training Model 2/20 ---
#
# --- Training Model 3/20 ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 5
#       3 for d in depths:
#       4     print(f"\n*** Running experiment for network with {d} depth***")
# ----> 5     bias_sq, variance, total_error,error_sum,avg_train_loss = estimate_bias_variance_mse(
#       6             model_class=MLPRegressor,
#       7             X_train=X_train,
#       8             y_train=y_train,
#       9             X_test=X_test,
#      10             y_test=y_test,
#      11             loss_fn=nn.MSELoss(),
#      12             model_kwargs={'input_dim':X_train.shape[1],"hidden_dim":hidden_units,'depth':d},
#      13             num_models=BOOTSTRAP_NUMS,
#      14             max_epochs=MAX_EPOCHS,
#      15             patience=PATIENCE,
#      16             lr=LEARNING_RATE,
#      17             batch_size=128
#      18         )
#      19     depth_results.append({
#      20             'depth': d,
#      21             'bias_sq': bias_sq,
#    (...)
#      25             'avg_train_loss':avg_train_loss
#      26         })
#
# File E:\Dissertation_Final\MSE loss\Sinusoidal Data\../../utils\Bias_Variance_Estimator.py:236, in estimate_bias_variance_mse(model_class, X_train, y_train, X_test, y_test, loss_fn, model_kwargs, num_models, max_epochs, patience, batch_size, lr, device)
#     233 train_data_list = [resample(X_train, y_train, replace=True) for _ in range(num_models)]
#     235 if isclass(model_class) and issubclass(model_class, nn.Module):
# --> 236     all_preds,train_loss=train_model(train_data_list,loss_fn,lr,model_class,model_kwargs,num_models,X_test,max_epochs,batch_size,
#     237                                                patience,device='cpu',task='regression')
#     238 else:
#     239     all_preds = train_model_sklearn(train_data_list, model_class, model_kwargs, X_test, task='regression')
#
# File E:\Dissertation_Final\MSE loss\Sinusoidal Data\../../utils\Bias_Variance_Estimator.py:115, in train_model(train_data_list, loss_fn, lr, model_class, model_kwargs, num_models, X_test, max_epochs, batch_size, patience, device, task)
#     113 model.eval()
#     114 with torch.no_grad():
# --> 115     val_output = model(X_val_tensor)
#     116     val_loss = loss_fn(val_output, y_val_tensor)
#     118 # print(f'Epoch {epoch+1}/{max_epochs}, Avg Train Loss: {epoch_loss/len(train_dataset):.4f}, Val Loss: {val_loss.item():.4f}')
#     119
#     120 # Early stopping check
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[18], line 35, in MLPRegressor.forward(self, x)
#      34 def forward(self, x):
# ---> 35     return self.net(x)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\nn\modules\container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
bias_values = [res['bias_sq'] for res in depth_results]
variance_values = [res['variance'] for res in depth_results]
error_values = [res['total_error'] for res in depth_results]
bias_plus_variance = [res['error_sum'] for res in depth_results]
    
plt.figure(figsize=(10, 6))
plt.plot(depths, bias_values, marker='o', label='Bias')
plt.plot(depths, variance_values, marker='s', label='Variance')
plt.plot(depths, error_values, marker='p', label='total error')
plt.plot(depths, bias_plus_variance, marker='p', label='bias + variance')

    
plt.xscale('log')
plt.xlabel('Depth of network')
plt.ylabel('Error')
plt.title('Bias and Variance Trends for Sinusoid Regression(Adam optimizer - Kaiming Initialization)')
plt.legend()
plt.grid(True)
plt.tight_layout()
