# %%
import sys
sys.path.append('../../utils/')

# %%
from Bias_Variance_Estimator import estimate_bias_variance_mse

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression,Ridge,Lasso,RidgeCV,LassoCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader,TensorDataset
import torch.optim as optim

# %%
import torchvision
from torchvision import datasets,transforms

# %%
class SinusoidNetwork(nn.Module):
    def __init__(self,input_dim,hidden_units):
        super(SinusoidNetwork,self).__init__()
        self.net= nn.Sequential(
            nn.Linear(input_dim,hidden_units),
            nn.ReLU(),
            nn.Linear(hidden_units,1)
        )
    def forward(self,x):
        return self.net(x)

# %%
def generate_sinusoid_data(num_samples:int,noise_scale:float=0.3):
    X = np.linspace(-1,1,num_samples).reshape(-1, 1)
    y_true = np.sin(2 * np.pi * X)                       # shape: (num_samples, 1)
    noise = np.random.normal(0, noise_scale, size=(num_samples, 1))#random gaussian noise
    y = y_true + noise
    return X,y

# %%
NUM_TRAIN_SAMPLES = 1000
NUM_TEST_SAMPLES = 5000
BOOTSTRAP_NUMS = 30
MAX_EPOCHS = 1000
PATIENCE = 1000
LEARNING_RATE=0.001
hidden_unit_sizes =[1,8,16,64,128,256,512,1024,2048,4096,8192]

# %%
X_train,y_train = generate_sinusoid_data(num_samples=NUM_TRAIN_SAMPLES)
X_test,y_test = generate_sinusoid_data(num_samples=NUM_TEST_SAMPLES,noise_scale=0)

# %%
results = []
for hidden_units in hidden_unit_sizes:
    print(f"---Training with {hidden_units} hidden units----")
    bias_sq,variance,total_error,error_sum,avg_train_loss= estimate_bias_variance_mse(
            model_class=SinusoidNetwork,
            X_train=X_train,
            y_train=y_train,
            X_test=X_test,
            y_test=y_test,
            loss_fn=nn.MSELoss(),
            model_kwargs={'input_dim':X_train.shape[1],"hidden_units":hidden_units},
            num_models=BOOTSTRAP_NUMS,
            max_epochs=MAX_EPOCHS,
            patience=PATIENCE,
            lr=LEARNING_RATE
        )
    results.append({
        'hidden_units': hidden_units,
        'bias_sq': bias_sq,
        'variance': variance,
        'total_error': total_error,
        'error_sum': error_sum,
        'avg_train_loss':avg_train_loss,
    })
# Out:
# ---Training with 1 hidden units----
# Starting experiment with 30 models...
#
# --- Training Model 1/30 ---
#
# --- Training Model 2/30 ---
#
# --- Training Model 3/30 ---
#
# --- Training Model 4/30 ---
#
# --- Training Model 5/30 ---
#
# --- Training Model 6/30 ---
#
# --- Training Model 7/30 ---
#
# --- Training Model 8/30 ---
#
# --- Training Model 9/30 ---
#
# --- Training Model 10/30 ---
#
# --- Training Model 11/30 ---
#
# --- Training Model 12/30 ---
#
# --- Training Model 13/30 ---
#
# --- Training Model 14/30 ---
#
# --- Training Model 15/30 ---
#
# --- Training Model 16/30 ---
#
# --- Training Model 17/30 ---
#
# --- Training Model 18/30 ---
#
# --- Training Model 19/30 ---
#
# --- Training Model 20/30 ---
#
# --- Training Model 21/30 ---
#
# --- Training Model 22/30 ---
#
# --- Training Model 23/30 ---
#
# --- Training Model 24/30 ---
#
# --- Training Model 25/30 ---
#
# --- Training Model 26/30 ---
#
# --- Training Model 27/30 ---
#
# --- Training Model 28/30 ---
#
# --- Training Model 29/30 ---
#
# --- Training Model 30/30 ---
#
# --- Final Results ---
# Bias:    0.4368
# Variance: 0.0272
# Total error: 0.4639
# Bias² + Variance: 0.4639
# ---Training with 8 hidden units----
# Starting experiment with 30 models...
#
# --- Training Model 1/30 ---
#
# --- Training Model 2/30 ---
#
# --- Training Model 3/30 ---
#
# --- Training Model 4/30 ---
#
# --- Training Model 5/30 ---
#
# --- Training Model 6/30 ---
#
# --- Training Model 7/30 ---
#
# --- Training Model 8/30 ---
#
# --- Training Model 9/30 ---
#
# --- Training Model 10/30 ---
#
# --- Training Model 11/30 ---
#
# --- Training Model 12/30 ---
#
# --- Training Model 13/30 ---
#
# --- Training Model 14/30 ---
#
# --- Training Model 15/30 ---
#
# --- Training Model 16/30 ---
#
# --- Training Model 17/30 ---
#
# --- Training Model 18/30 ---
#
# --- Training Model 19/30 ---
#
# --- Training Model 20/30 ---
#
# --- Training Model 21/30 ---
#
# --- Training Model 22/30 ---
#
# --- Training Model 23/30 ---
#
# --- Training Model 24/30 ---
#
# --- Training Model 25/30 ---
#
# --- Training Model 26/30 ---
#
# --- Training Model 27/30 ---
#
# --- Training Model 28/30 ---
#
# --- Training Model 29/30 ---
#
# --- Training Model 30/30 ---
#
# --- Final Results ---
# Bias:    0.3361
# Variance: 0.0138
# Total error: 0.3499
# Bias² + Variance: 0.3499
# ---Training with 16 hidden units----
# Starting experiment with 30 models...
#
# --- Training Model 1/30 ---
#
# --- Training Model 2/30 ---
#
# --- Training Model 3/30 ---
#
# --- Training Model 4/30 ---
#
# --- Training Model 5/30 ---
#
# --- Training Model 6/30 ---
#
# --- Training Model 7/30 ---
#
# --- Training Model 8/30 ---
#
# --- Training Model 9/30 ---
#
# --- Training Model 10/30 ---
#
# --- Training Model 11/30 ---
#
# --- Training Model 12/30 ---
#
# --- Training Model 13/30 ---
#
# --- Training Model 14/30 ---
#
# --- Training Model 15/30 ---
#
# --- Training Model 16/30 ---
#
# --- Training Model 17/30 ---
#
# --- Training Model 18/30 ---
#
# --- Training Model 19/30 ---
#
# --- Training Model 20/30 ---
#
# --- Training Model 21/30 ---
#
# --- Training Model 22/30 ---
#
# --- Training Model 23/30 ---
#
# --- Training Model 24/30 ---
#
# --- Training Model 25/30 ---
#
# --- Training Model 26/30 ---
#
# --- Training Model 27/30 ---
#
# --- Training Model 28/30 ---
#
# --- Training Model 29/30 ---
#
# --- Training Model 30/30 ---
#
# --- Final Results ---
# Bias:    0.2382
# Variance: 0.0183
# Total error: 0.2565
# Bias² + Variance: 0.2565
# ---Training with 64 hidden units----
# Starting experiment with 30 models...
#
# --- Training Model 1/30 ---
#
# --- Training Model 2/30 ---
#
# --- Training Model 3/30 ---
#
# --- Training Model 4/30 ---
#
# --- Training Model 5/30 ---
#
# --- Training Model 6/30 ---
#
# --- Training Model 7/30 ---
#
# --- Training Model 8/30 ---
#
# --- Training Model 9/30 ---
#
# --- Training Model 10/30 ---
#
# --- Training Model 11/30 ---
#
# --- Training Model 12/30 ---
#
# --- Training Model 13/30 ---
#
# --- Training Model 14/30 ---
#
# --- Training Model 15/30 ---
#
# --- Training Model 16/30 ---
#
# --- Training Model 17/30 ---
#
# --- Training Model 18/30 ---
#
# --- Training Model 19/30 ---
#
# --- Training Model 20/30 ---
#
# --- Training Model 21/30 ---
#
# --- Training Model 22/30 ---
#
# --- Training Model 23/30 ---
#
# --- Training Model 24/30 ---
#
# --- Training Model 25/30 ---
#
# --- Training Model 26/30 ---
#
# --- Training Model 27/30 ---
#
# --- Training Model 28/30 ---
#
# --- Training Model 29/30 ---
#
# --- Training Model 30/30 ---
#
# --- Final Results ---
# Bias:    0.0487
# Variance: 0.0105
# Total error: 0.0593
# Bias² + Variance: 0.0593
# ---Training with 128 hidden units----
# Starting experiment with 30 models...
#
# --- Training Model 1/30 ---
#
# --- Training Model 2/30 ---
#
# --- Training Model 3/30 ---
#
# --- Training Model 4/30 ---
#
# --- Training Model 5/30 ---
#
# --- Training Model 6/30 ---
#
# --- Training Model 7/30 ---
#
# --- Training Model 8/30 ---
#
# --- Training Model 9/30 ---
#
# --- Training Model 10/30 ---
#
# --- Training Model 11/30 ---
#
# --- Training Model 12/30 ---
#
# --- Training Model 13/30 ---
#
# --- Training Model 14/30 ---
#
# --- Training Model 15/30 ---
#
# --- Training Model 16/30 ---
#
# --- Training Model 17/30 ---
#
# --- Training Model 18/30 ---
#
# --- Training Model 19/30 ---
#
# --- Training Model 20/30 ---
#
# --- Training Model 21/30 ---
#
# --- Training Model 22/30 ---
#
# --- Training Model 23/30 ---
#
# --- Training Model 24/30 ---
#
# --- Training Model 25/30 ---
#
# --- Training Model 26/30 ---
#
# --- Training Model 27/30 ---
#
# --- Training Model 28/30 ---
#
# --- Training Model 29/30 ---
#
# --- Training Model 30/30 ---
#
# --- Final Results ---
# Bias:    0.0093
# Variance: 0.0045
# Total error: 0.0137
# Bias² + Variance: 0.0137
# ---Training with 256 hidden units----
# Starting experiment with 30 models...
#
# --- Training Model 1/30 ---
#
# --- Training Model 2/30 ---
#
# --- Training Model 3/30 ---
#
# --- Training Model 4/30 ---
#
# --- Training Model 5/30 ---
#
# --- Training Model 6/30 ---
#
# --- Training Model 7/30 ---
#
# --- Training Model 8/30 ---
#
# --- Training Model 9/30 ---
#
# --- Training Model 10/30 ---
#
# --- Training Model 11/30 ---
#
# --- Training Model 12/30 ---
#
# --- Training Model 13/30 ---
#
# --- Training Model 14/30 ---
#
# --- Training Model 15/30 ---
#
# --- Training Model 16/30 ---
#
# --- Training Model 17/30 ---
#
# --- Training Model 18/30 ---
#
# --- Training Model 19/30 ---
#
# --- Training Model 20/30 ---
#
# --- Training Model 21/30 ---
#
# --- Training Model 22/30 ---
#
# --- Training Model 23/30 ---
#
# --- Training Model 24/30 ---
#
# --- Training Model 25/30 ---
#
# --- Training Model 26/30 ---
#
# --- Training Model 27/30 ---
#
# --- Training Model 28/30 ---
#
# --- Training Model 29/30 ---
#
# --- Training Model 30/30 ---
#
# --- Final Results ---
# Bias:    0.0045
# Variance: 0.0021
# Total error: 0.0066
# Bias² + Variance: 0.0066
# ---Training with 512 hidden units----
# Starting experiment with 30 models...
#
# --- Training Model 1/30 ---
#
# --- Training Model 2/30 ---
#
# --- Training Model 3/30 ---
#
# --- Training Model 4/30 ---
#
# --- Training Model 5/30 ---
#
# --- Training Model 6/30 ---
#
# --- Training Model 7/30 ---
#
# --- Training Model 8/30 ---
#
# --- Training Model 9/30 ---
#
# --- Training Model 10/30 ---
#
# --- Training Model 11/30 ---
#
# --- Training Model 12/30 ---
#
# --- Training Model 13/30 ---
#
# --- Training Model 14/30 ---
#
# --- Training Model 15/30 ---
#
# --- Training Model 16/30 ---
#
# --- Training Model 17/30 ---
#
# --- Training Model 18/30 ---
#
# --- Training Model 19/30 ---
#
# --- Training Model 20/30 ---
#
# --- Training Model 21/30 ---
#
# --- Training Model 22/30 ---
#
# --- Training Model 23/30 ---
#
# --- Training Model 24/30 ---
#
# --- Training Model 25/30 ---
#
# --- Training Model 26/30 ---
#
# --- Training Model 27/30 ---
#
# --- Training Model 28/30 ---
#
# --- Training Model 29/30 ---
#
# --- Training Model 30/30 ---
#
# --- Final Results ---
# Bias:    0.0033
# Variance: 0.0019
# Total error: 0.0051
# Bias² + Variance: 0.0051
# ---Training with 1024 hidden units----
# Starting experiment with 30 models...
#
# --- Training Model 1/30 ---
#
# --- Training Model 2/30 ---
#
# --- Training Model 3/30 ---
#
# --- Training Model 4/30 ---
#
# --- Training Model 5/30 ---
#
# --- Training Model 6/30 ---
#
# --- Training Model 7/30 ---
#
# --- Training Model 8/30 ---
#
# --- Training Model 9/30 ---
#
# --- Training Model 10/30 ---
#
# --- Training Model 11/30 ---
#
# --- Training Model 12/30 ---
#
# --- Training Model 13/30 ---
#
# --- Training Model 14/30 ---
#
# --- Training Model 15/30 ---
#
# --- Training Model 16/30 ---
#
# --- Training Model 17/30 ---
#
# --- Training Model 18/30 ---
#
# --- Training Model 19/30 ---
#
# --- Training Model 20/30 ---
#
# --- Training Model 21/30 ---
#
# --- Training Model 22/30 ---
#
# --- Training Model 23/30 ---
#
# --- Training Model 24/30 ---
#
# --- Training Model 25/30 ---
#
# --- Training Model 26/30 ---
#
# --- Training Model 27/30 ---
#
# --- Training Model 28/30 ---
#
# --- Training Model 29/30 ---
#
# --- Training Model 30/30 ---
#
# --- Final Results ---
# Bias:    0.0032
# Variance: 0.0017
# Total error: 0.0049
# Bias² + Variance: 0.0049
# ---Training with 2048 hidden units----
# Starting experiment with 30 models...
#
# --- Training Model 1/30 ---
#
# --- Training Model 2/30 ---
#
# --- Training Model 3/30 ---
#
# --- Training Model 4/30 ---
#
# --- Training Model 5/30 ---
#
# --- Training Model 6/30 ---
#
# --- Training Model 7/30 ---
#
# --- Training Model 8/30 ---
#
# --- Training Model 9/30 ---
#
# --- Training Model 10/30 ---
#
# --- Training Model 11/30 ---
#
# --- Training Model 12/30 ---
#
# --- Training Model 13/30 ---
#
# --- Training Model 14/30 ---
#
# --- Training Model 15/30 ---
#
# --- Training Model 16/30 ---
#
# --- Training Model 17/30 ---
#
# --- Training Model 18/30 ---
#
# --- Training Model 19/30 ---
#
# --- Training Model 20/30 ---
#
# --- Training Model 21/30 ---
#
# --- Training Model 22/30 ---
#
# --- Training Model 23/30 ---
#
# --- Training Model 24/30 ---
#
# --- Training Model 25/30 ---
#
# --- Training Model 26/30 ---
#
# --- Training Model 27/30 ---
#
# --- Training Model 28/30 ---
#
# --- Training Model 29/30 ---
#
# --- Training Model 30/30 ---
#
# --- Final Results ---
# Bias:    0.0027
# Variance: 0.0018
# Total error: 0.0045
# Bias² + Variance: 0.0045
# ---Training with 4096 hidden units----
# Starting experiment with 30 models...
#
# --- Training Model 1/30 ---
#
# --- Training Model 2/30 ---
#
# --- Training Model 3/30 ---
#
# --- Training Model 4/30 ---
#
# --- Training Model 5/30 ---
#
# --- Training Model 6/30 ---
#
# --- Training Model 7/30 ---
#
# --- Training Model 8/30 ---
#
# --- Training Model 9/30 ---
#
# --- Training Model 10/30 ---
#
# --- Training Model 11/30 ---
#
# --- Training Model 12/30 ---
#
# --- Training Model 13/30 ---
#
# --- Training Model 14/30 ---
#
# --- Training Model 15/30 ---
#
# --- Training Model 16/30 ---
#
# --- Training Model 17/30 ---
#
# --- Training Model 18/30 ---
#
# --- Training Model 19/30 ---
#
# --- Training Model 20/30 ---
#
# --- Training Model 21/30 ---
#
# --- Training Model 22/30 ---
#
# --- Training Model 23/30 ---
#
# --- Training Model 24/30 ---
#
# --- Training Model 25/30 ---
#
# --- Training Model 26/30 ---
#
# --- Training Model 27/30 ---
#
# --- Training Model 28/30 ---
#
# --- Training Model 29/30 ---
#
# --- Training Model 30/30 ---
#
# --- Final Results ---
# Bias:    0.0022
# Variance: 0.0024
# Total error: 0.0046
# Bias² + Variance: 0.0046
# ---Training with 8192 hidden units----
# Starting experiment with 30 models...
#
# --- Training Model 1/30 ---
#
# --- Training Model 2/30 ---
#
# --- Training Model 3/30 ---
#
# --- Training Model 4/30 ---
#
# --- Training Model 5/30 ---
#
# --- Training Model 6/30 ---
#
# --- Training Model 7/30 ---
#
# --- Training Model 8/30 ---
#
# --- Training Model 9/30 ---
#
# --- Training Model 10/30 ---
#
# --- Training Model 11/30 ---
#
# --- Training Model 12/30 ---
#
# --- Training Model 13/30 ---
#
# --- Training Model 14/30 ---
#
# --- Training Model 15/30 ---
#
# --- Training Model 16/30 ---
#
# --- Training Model 17/30 ---
#
# --- Training Model 18/30 ---
#
# --- Training Model 19/30 ---
#
# --- Training Model 20/30 ---
#
# --- Training Model 21/30 ---
#
# --- Training Model 22/30 ---
#
# --- Training Model 23/30 ---
#
# --- Training Model 24/30 ---
#
# --- Training Model 25/30 ---
#
# --- Training Model 26/30 ---
#
# --- Training Model 27/30 ---
#
# --- Training Model 28/30 ---
#
# --- Training Model 29/30 ---
#
# --- Training Model 30/30 ---
#
# --- Final Results ---
# Bias:    0.0016
# Variance: 0.0068
# Total error: 0.0084
# Bias² + Variance: 0.0084

# %%
results
# Out:
# [{'hidden_units': 1,
#   'bias_sq': np.float64(0.43675652984655583),
#   'variance': np.float32(0.027164634),
#   'total_error': np.float64(0.4639211644630095),
#   'error_sum': np.float64(0.4639211641637155),
#   'avg_train_loss': np.float64(0.6613796699355046)},
#  {'hidden_units': 8,
#   'bias_sq': np.float64(0.33611654673645563),
#   'variance': np.float32(0.013811187),
#   'total_error': np.float64(0.3499277350031599),
#   'error_sum': np.float64(0.3499277336237795),
#   'avg_train_loss': np.float64(0.49622292380432287)},
#  {'hidden_units': 16,
#   'bias_sq': np.float64(0.2382384141064049),
#   'variance': np.float32(0.018282387),
#   'total_error': np.float64(0.25652080207562633),
#   'error_sum': np.float64(0.2565208015120388),
#   'avg_train_loss': np.float64(0.4438334792902072)},
#  {'hidden_units': 64,
#   'bias_sq': np.float64(0.04872691613744352),
#   'variance': np.float32(0.01054653),
#   'total_error': np.float64(0.05927344624354215),
#   'error_sum': np.float64(0.05927344580303285),
#   'avg_train_loss': np.float64(0.29167768100723623)},
#  {'hidden_units': 128,
#   'bias_sq': np.float64(0.009270363011783104),
#   'variance': np.float32(0.0044700205),
#   'total_error': np.float64(0.013740382904773732),
#   'error_sum': np.float64(0.013740383544391136),
#   'avg_train_loss': np.float64(0.2120685428691407)},
#  {'hidden_units': 256,
#   'bias_sq': np.float64(0.004536253559545963),
#   'variance': np.float32(0.0020879288),
#   'total_error': np.float64(0.006624182372294943),
#   'error_sum': np.float64(0.006624182379947393),
#   'avg_train_loss': np.float64(0.173017965379109)},
#  {'hidden_units': 512,
#   'bias_sq': np.float64(0.003276326394425648),
#   'variance': np.float32(0.0018618621),
#   'total_error': np.float64(0.005138188302534909),
#   'error_sum': np.float64(0.005138188534201997),
#   'avg_train_loss': np.float64(0.1448545474457244)},
#  {'hidden_units': 1024,
#   'bias_sq': np.float64(0.00315565396277641),
#   'variance': np.float32(0.0017222337),
#   'total_error': np.float64(0.004877887676084207),
#   'error_sum': np.float64(0.0048778876819688555),
#   'avg_train_loss': np.float64(0.12220041187678775)},
#  {'hidden_units': 2048,
#   'bias_sq': np.float64(0.0026573062236738415),
#   'variance': np.float32(0.001831421),
#   'total_error': np.float64(0.004488727211759628),
#   'error_sum': np.float64(0.004488727270191631),
#   'avg_train_loss': np.float64(0.11091552234316866)},
#  {'hidden_units': 4096,
#   'bias_sq': np.float64(0.0022156181846929336),
#   'variance': np.float32(0.0024267829),
#   'total_error': np.float64(0.004642401174303552),
#   'error_sum': np.float64(0.004642401040456965),
#   'avg_train_loss': np.float64(0.10701618964249889)},
#  {'hidden_units': 8192,
#   'bias_sq': np.float64(0.0015990980154844908),
#   'variance': np.float32(0.006788617),
#   'total_error': np.float64(0.008387715289171968),
#   'error_sum': np.float64(0.008387715015468278),
#   'avg_train_loss': np.float64(0.11789358714570602)}]

# %%
bias_sq = [r['bias_sq'] for r in results]
variance = [r['variance'] for r in results]
total_error = [r['total_error'] for r in results]
avg_train_loss = [r['avg_train_loss'] for r in results]

# --- Plot 1: Bias, Variance, Total Error ---
plt.figure(figsize=(10, 6))
plt.plot(hidden_unit_sizes, bias_sq, marker='o', label='Bias²')
plt.plot(hidden_unit_sizes, variance, marker='o', label='Variance')
plt.plot(hidden_unit_sizes, total_error, marker='o', label='Total Error')
plt.xscale('log')  # Log scale for hidden units
plt.xlabel('Size of Hidden Units (log scale)')
plt.ylabel('Error')
plt.title('Bias-Variance-Total Error vs Hidden Units (Sinusoidal dataset)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(hidden_unit_sizes, variance, marker='o', label='Variance')
plt.xscale('log')  # Log scale for hidden units
plt.xlabel('Size of Hidden Units (log scale)')
plt.ylabel('Variance')
# Out:
# Text(0, 0.5, 'Variance')

# %%
plt.figure(figsize=(10, 6))
plt.plot(hidden_unit_sizes, avg_train_loss, marker='o', label='Avg Train Loss')
plt.plot(hidden_unit_sizes, total_error, marker='o', label='Total Error')
plt.xscale('log')  # Log scale for hidden units
plt.xlabel('Size of Hidden Units (log scale)')
plt.ylabel('Error')
plt.title('Avg Train Loss and Total Error vs Hidden Units')
plt.legend()
plt.grid(True)
plt.show()

# %%
bias_sq = [r['bias_sq'] for r in results]
variance = [r['variance'] for r in results]


x = np.arange(len(hidden_unit_sizes))  
width = 0.35  
plt.figure(figsize=(12, 6))
plt.bar(x - width/2, bias_sq, width, label='Bias²')
plt.bar(x + width/2, variance, width, label='Variance')


plt.xticks(x, hidden_unit_sizes, rotation=45)
plt.xlabel('Hidden Units')
plt.ylabel('Error')
plt.title('Bias² and Variance Across Hidden Units')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
